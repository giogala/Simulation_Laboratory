# %% [markdown]
# ----
# ## Esercizio 1.2
# ----

# %% [markdown]
# ### Parte 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data.txt',sep='\t')
plt.hist(df.iloc[:,0],bins='auto')
plt.grid(True)
plt.show()

# %%
plt.hist(df.iloc[:,1],range=(-5,5),bins='auto')
plt.grid(True)
plt.show()

# %%
plt.hist(df.iloc[:,2],range=(-4,6),bins='auto')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Parte 2

# %%
du = pd.read_csv('Data_u.txt',sep='\t')

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 4))

for i in range(0,4):
    axes[i].hist(du.iloc[:,i],bins='auto')

# %%
de = pd.read_csv('Data_e.txt',sep='\t')

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 4))

for i in range(0,4):
    axes[i].hist(de.iloc[:,i],bins='auto')

# %%
dc = pd.read_csv('Data_c.txt',sep='\t')

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 4))

for i in range(0,4):
    axes[i].hist(dc.iloc[:,i],range=(-5,5),bins='auto')
